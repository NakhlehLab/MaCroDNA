# %%
import pandas as pd
import numpy as np

# %%
rna_data = pd.read_csv("all_gene_id_name.csv", index_col=0)
rna_data
# Out:
#           CRC02_ML4_216  CRC01_PT3_386  CRC01_ML2_055  CRC06_PT4_296  \
# A1BG                  0              0              0              0
# A1BG-AS1              0              0              0              0
# A1CF                 15              0              7              0
# A2M                   0              0              0              0
# A2M-AS1               0              0              0              0
# ...                 ...            ...            ...            ...
# ZYG11A                0              0              0              0
# ZYG11B                2              0              0              0
# ZYX                 196            137            148            117
# ZZEF1                 0              0              0              0
# ZZZ3                  0              0             10              0
#
#           CRC01_MP1_131  CRC01_ML1_038  CRC10_PT3_101  CRC01_LN3_243  \
# ...

# %%
rna_data = rna_data.groupby(["gene_id"]).sum()
rna_data
# Out:
#                  CRC02_ML4_216  CRC01_PT3_386  CRC01_ML2_055  CRC06_PT4_296  \
# gene_id
# ENSG00000000003             10              2             68              0
# ENSG00000000005              0              0              0              0
# ENSG00000000419             29             48             13              0
# ENSG00000000457              0              0              0              0
# ENSG00000000460              0              0              0            183
# ...                        ...            ...            ...            ...
# ENSG00000288701              0              0             19              0
# ENSG00000288702              0              0              0              0
# ENSG00000288705              0              0              0              0
# ENSG00000288709              0              0              0              0
# ENSG00000288722              0              9              0              0
#
# ...

# %%
rna_data.index = list(rna_data.index)
rna_data
# Out:
#                  CRC02_ML4_216  CRC01_PT3_386  CRC01_ML2_055  CRC06_PT4_296  \
# ENSG00000000003             10              2             68              0
# ENSG00000000005              0              0              0              0
# ENSG00000000419             29             48             13              0
# ENSG00000000457              0              0              0              0
# ENSG00000000460              0              0              0            183
# ...                        ...            ...            ...            ...
# ENSG00000288701              0              0             19              0
# ENSG00000288702              0              0              0              0
# ENSG00000288705              0              0              0              0
# ENSG00000288709              0              0              0              0
# ENSG00000288722              0              9              0              0
#
# ...

# %%
rna_data.to_csv("all_rna_processed.csv", header=True,index=True)

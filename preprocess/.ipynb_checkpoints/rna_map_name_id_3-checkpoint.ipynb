# %%
import pandas as pd
import numpy as np

# %%
rna_data = pd.read_csv("../Data/all_gene_id_name.csv", index_col=0)
rna_data
# Out:
#           CRC01_MP4_080  CRC06_LN1_037  CRC06_PT2_180  CRC09_PT4_547  \
# A1BG                  0              0              0              0
# A1BG-AS1              0              0              0              0
# A1CF                  0             42              0            208
# A2M                   0              3              0              0
# A2M-AS1               0              0              0              0
# ...                 ...            ...            ...            ...
# ZYG11A                0              0              0              0
# ZYG11B                0              0             21              0
# ZYX                   1            126             53              0
# ZZEF1                 0              0             11              0
# ZZZ3                  0             63              0              0
#
#           CRC11_PT4_712  CRC01_LN1_171  CRC11_PT4_736  CRC01_LN3_246  \
# ...

# %%
rna_data = rna_data.groupby(["gene_id"]).sum()
rna_data
# Out:
#                  CRC01_MP4_080  CRC06_LN1_037  CRC06_PT2_180  CRC09_PT4_547  \
# gene_id
# ENSG00000000003              1            147            286            208
# ENSG00000000005              0              0              0              0
# ENSG00000000419              0            210            414            292
# ENSG00000000457              1              0              0              0
# ENSG00000000460              0             35              0              0
# ...                        ...            ...            ...            ...
# ENSG00000288701              0             87             42             83
# ENSG00000288702              0              0              0              0
# ENSG00000288705              0              0              0              0
# ENSG00000288709              0              0              0              0
# ENSG00000288722              0              0              0              0
#
# ...

# %%
rna_data.index = list(rna_data.index)
rna_data
# Out:
#                  CRC01_MP4_080  CRC06_LN1_037  CRC06_PT2_180  CRC09_PT4_547  \
# ENSG00000000003              1            147            286            208
# ENSG00000000005              0              0              0              0
# ENSG00000000419              0            210            414            292
# ENSG00000000457              1              0              0              0
# ENSG00000000460              0             35              0              0
# ...                        ...            ...            ...            ...
# ENSG00000288701              0             87             42             83
# ENSG00000288702              0              0              0              0
# ENSG00000288705              0              0              0              0
# ENSG00000288709              0              0              0              0
# ENSG00000288722              0              0              0              0
#
# ...

# %%
rna_data.to_csv("../Data/all_rna_processed.csv", header=True,index=True)
